# %%
import pymongo

# %%
from pymongo import MongoClient

# %%
connection_string="mongodb+srv://satyajit2164_db_user:9cXB7tnDURnpMjqV@cluster0.c8m40km.mongodb.net/?appName=Cluster0"

# %%
client=MongoClient(connection_string)
db=client["liveclass"]
collection=db["mongoclass"]

# %%
data={
    "name":"satya",
    "age":22,
    "email":"satyajit2164@gmail.com"
}

# %%
collection.insert_one(data)

# %%
cursor=collection.find({})
for i in cursor:
    print(i)
# Out:
# {'_id': ObjectId('698c8b30dc96ab1020b6f11c'), 'name': 'satya', 'age': 22, 'email': 'satyajit2164@gmail.com'}
